# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# html = r"https://response.epa.gov/site/region_list.aspx?region=5"
html = r"Regions - EPA OSC Response.html"
base_html = r"https://response.epa.gov/site/"

# %%
f = open(html)

# %%
# page = requests.get(html)
# page

# %%
# soup = BeautifulSoup(page.content, 'html.parser')
soup = BeautifulSoup(f, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0055)https://response.epa.gov/site/region_list.aspx?region=5 -->
# <html class=" js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths" lang="en" style="">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="noindex,follow" name="robots"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Regions - EPA OSC Response
#   </title>
# ...

# %%
div_id = "ctl00_cp1_pnlRptGrid"

# %%
html = list(soup.children)[4]

# %%
tablerecords = list(soup.find_all('a', class_="NormalColoredFont"))

# %%
site_url_params_list = []
for record in tablerecords:
    try:
        if record['href'] and record['href'][:47] == "https://response.epa.gov/site/site_profile.aspx":
#         if record['href'] and record['href'][:12] == "site_profile":
            site_url_params_list.append(record['href'])
    except KeyError:
        pass
    
site_url_params_list
# Out:
# ['https://response.epa.gov/site/site_profile.aspx?site_id=11006',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12868',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12875',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12580',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12842',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12107',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12410',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=11657',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12521',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=9627',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=3806',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12337',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=11094',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12208',
# ...

# %%
site_url_list = [url_param for url_param in site_url_params_list]
site_url_list
# Out:
# ['https://response.epa.gov/site/site_profile.aspx?site_id=11006',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12868',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12875',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12580',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12842',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12107',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12410',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=11657',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12521',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=9627',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=3806',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12337',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=11094',
#  'https://response.epa.gov/site/site_profile.aspx?site_id=12208',
# ...

# %%
len(site_url_list)
# Out:
# 1285

# %%
site_url_generator = (url_param for url_param in site_url_params_list)
site_url_generator
# Out:
# <generator object <genexpr> at 0x0000016B03036D00>

# %%
for site_url in site_url_generator:
    print(site_url)
# Out:
# https://response.epa.gov/site/site_profile.aspx?site_id=11006
# https://response.epa.gov/site/site_profile.aspx?site_id=12868
# https://response.epa.gov/site/site_profile.aspx?site_id=12875
# https://response.epa.gov/site/site_profile.aspx?site_id=12580
# https://response.epa.gov/site/site_profile.aspx?site_id=12842
# https://response.epa.gov/site/site_profile.aspx?site_id=12107
# https://response.epa.gov/site/site_profile.aspx?site_id=12410
# https://response.epa.gov/site/site_profile.aspx?site_id=11657
# https://response.epa.gov/site/site_profile.aspx?site_id=12521
# https://response.epa.gov/site/site_profile.aspx?site_id=9627
# https://response.epa.gov/site/site_profile.aspx?site_id=3806
# https://response.epa.gov/site/site_profile.aspx?site_id=12337
# https://response.epa.gov/site/site_profile.aspx?site_id=11094
# https://response.epa.gov/site/site_profile.aspx?site_id=12208
# https://response.epa.gov/site/site_profile.aspx?site_id=12635
# ...

# %%
site_url_list[0]
# Out:
# 'https://response.epa.gov/site/site_profile.aspx?site_id=11006'

# %%
page = requests.get(site_url_list[0])
page
# Out:
# <Response [200]>

# %%
site_soup = BeautifulSoup(page.content, 'html.parser')

# %%
site_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta content="nofollow,noarchive" name="robots"/><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><title>
# 	Site Profile - Otsego Township Dam Area - EPA OSC Response
# </title>
# <!--FMM: Order of loading files important for IE8 compatibilty and to reduce screen flicker as CSS is applied to page -->
# <script src="/js/jquery-1.10.2.js" type="text/javascript"></script>
# <script src="/js/bootstrap.min.js" type="text/javascript"></script>
# ...

# %%
contact_records = list(site_soup.find_all('p', id_="ctl00_cp1_lblLatitude"))
contact_records
# Out:
# []

# %%
page.url
# Out:
# 'https://response.epa.gov/site/site_profile.aspx?site_id=11006'
